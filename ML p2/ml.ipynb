# %%
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
dataframe = pd.read_csv("diabetes.csv")
dataframe.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
fitur = dataframe.iloc[:,:-1] 
label = dataframe.iloc[:,-1]

# %%
fitur.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
label.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
print ("max glukosa : ", fitur['Glucose'].max())
print ("min glukosa : ", fitur['Glucose'].min())
# Out:
# max glukosa :  199
# min glukosa :  0

# %%
import matplotlib.pyplot as mpp
mpp.figure(figsize=(5,5))
sb.scatterplot(dataframe["Glucose"], dataframe["BloodPressure"], hue=dataframe['Outcome'],palette="gist_rainbow", marker ='x')

# %%
dataframe.groupby(['Outcome']).describe()
# Out:
#         Pregnancies                                                Glucose  \
#               count      mean       std  min   25%  50%  75%   max   count
# Outcome
# 0             500.0  3.298000  3.017185  0.0  1.00  2.0  5.0  13.0   500.0
# 1             268.0  4.865672  3.741239  0.0  1.75  4.0  8.0  17.0   268.0
#
#                      ... DiabetesPedigreeFunction           Age             \
#                mean  ...                      75%    max  count       mean
# Outcome              ...
# 0        109.980000  ...                  0.56175  2.329  500.0  31.190000
# 1        141.257463  ...                  0.72800  2.420  268.0  37.067164
#
#
#                std   min   25%   50%   75%   max
# Outcome
# 0        11.667655  21.0  23.0  27.0  37.0  81.0
# 1        10.968254  21.0  28.0  36.0  44.0  70.0
#
# [2 rows x 64 columns]

# %%
dataframe.groupby(['Outcome'])[["Glucose"]].mean()
# Out:
#             Glucose
# Outcome
# 0        109.980000
# 1        141.257463

# %%
dataframe.groupby(['Outcome'])[["Insulin"]].mean()
# Out:
#             Insulin
# Outcome
# 0         68.792000
# 1        100.335821

# %%
dataframe.groupby(['Outcome'])[["BloodPressure"]].max()
# Out:
#          BloodPressure
# Outcome
# 0                  122
# 1                  114
